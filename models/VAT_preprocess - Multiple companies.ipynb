# %%
import pandas as pd
from pprint import pprint
import numpy as np
import json
from glob import glob

# %%
IS_ACCOUNTS = ["Net sales",
            "Cost of goods sold",
            "Gross Profit",
            "Financial expenses",
            "Of which: Interest expense",
            "Cost of sales",
            "Enterprise cost management",
            "Total Operating Expenses",
            "Total revenue financing activities",
            "Net profit from business activities",
            "Profit",
            "Profit before tax",
            "Present corporate income tax expenses",
            "Deferred income taxes expenses",
            "The interests of minority shareholders",
            "Total Cost of profits",
            "Profit after tax corporate income",
            "Volume",
            "Close of Quarter",
            "EPS",
            "Non-adjusted EPS",
            "PE",
            "Book Price"]

# %%
# GET ALL DATA FROM AN ACCOUNT TO A LIST, TREATING 'N/A' AS np.nan
def process_array(row, status, account, list_to_array):
    if row[status][account] == 'N/A':
        list_to_array.append(np.nan)
    else:
        list_to_array.append(row[status][account])

# %%
files = sorted(glob("jsons/" + "*.json"))

# %%
dict_main = {}
for file in files:
    DF_file = pd.read_json(file)
    DF_file['index'] = np.array([row['quarter'] for row in DF_file['data']])
    DF_file.set_index('index', inplace=True)
    try:
        dict_main[DF_file['ticker'][0]] = DF_file
    except:
        pass    
# panel_main = pd.Panel(dict_main)

print ("The tickers are:")
print (dict_main.keys())
# Out:
# The tickers are:
# dict_keys(['AAA', 'AAM', 'ABI', 'ABT', 'ACB', 'ACC', 'ACE', 'ACL', 'ACM', 'ADC', 'ADP', 'ADS', 'AGC', 'AGD', 'AGF', 'AGM', 'AGR', 'ALP', 'ALT', 'ALV', 'AMC', 'AMD', 'AME', 'AMV', 'ANV', 'APC', 'APG', 'API', 'APP', 'APS', 'ARM', 'ASA', 'ASD', 'ASM', 'ASP', 'ATA', 'ATS', 'AVF', 'AVS'])

# %% [markdown]
# ### Now we process each ticker's data

# %%
for ticker, ticker_df in dict_main.items():
    arr = [ [] for account in IS_ACCOUNTS ]
    for row in ticker_df['data']:
        process_array(row, 'income status', 'Net sales', arr[0])
    net_sales = np.array(arr[0])
    ticker_df['net_sales_normalized'] = (net_sales - np.nanmean(net_sales)) / np.nanstd(net_sales)
# Out:
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    AAA
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    AAA
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    AAA
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    AAA
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    AAA
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    AAA
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    AAA
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    AAA
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    AAA
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    AAA
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    AAA
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    AAA
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    AAA
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    AAA
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    AAA
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    AAA
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    AAA
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    AAA
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    AAA
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    AAA
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    AAA
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    AAA
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    AAA
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    AAA
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    AAA
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    AAA
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    AAA
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    AAA
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    AAA
#
#          net_sales_normalized
# index
# Q1 2017              2.698701
# Q4 2016              2.275765
# Q3 2016              1.363909
# Q2 2016              1.236116
# Q1 2016              0.589673
# Q4 2015              0.838929
# Q3 2015              0.892971
# Q2 2015              0.213419
# Q1 2015             -0.137155
# Q4 2014              0.732863
# Q3 2014              0.491223
# Q2 2014              0.315297
# Q1 2014             -0.103749
# Q4 2013             -0.067433
# Q3 2013             -0.201722
# Q2 2013             -0.429527
# Q1 2013             -0.651645
# Q4 2012             -0.368346
# Q3 2012             -0.652654
# Q2 2012             -0.840598
# Q1 2012             -0.507881
# Q4 2011             -0.338561
# Q3 2011             -0.797336
# Q2 2011             -0.929504
# Q1 2011             -0.990996
# Q4 2010             -0.951853
# Q3 2010             -0.945295
# Q2 2010             -1.240397
# Q1 2010             -1.494214
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    AAM
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    AAM
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    AAM
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    AAM
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    AAM
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    AAM
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    AAM
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    AAM
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    AAM
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    AAM
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    AAM
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    AAM
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    AAM
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    AAM
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    AAM
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    AAM
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    AAM
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    AAM
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    AAM
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    AAM
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    AAM
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    AAM
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    AAM
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    AAM
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    AAM
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    AAM
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    AAM
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    AAM
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    AAM
# Q4 2009  {'quarter': 'Q4 2009', 'income status': {'Net ...    AAM
# Q3 2009  {'quarter': 'Q3 2009', 'income status': {'Net ...    AAM
# Q2 2009  {'quarter': 'Q2 2009', 'income status': {'Net ...    AAM
# Q1 2009  {'quarter': 'Q1 2009', 'income status': {'Net ...    AAM
# Q4 2008  {'quarter': 'Q4 2008', 'income status': {'Net ...    AAM
# Q3 2008  {'quarter': 'Q3 2008', 'income status': {'Net ...    AAM
#
#          net_sales_normalized
# index
# Q1 2017             -1.932815
# Q4 2016             -1.166018
# Q3 2016             -1.494726
# Q2 2016             -1.520702
# Q1 2016             -1.345264
# Q4 2015             -0.950752
# Q3 2015             -0.277844
# Q2 2015             -0.618706
# Q1 2015             -1.322595
# Q4 2014             -0.521951
# Q3 2014             -0.346671
# Q2 2014              0.458223
# Q1 2014              0.054863
# Q4 2013              1.288905
# Q3 2013              1.140167
# Q2 2013              0.239935
# Q1 2013             -0.050110
# Q4 2012              0.727865
# Q3 2012             -0.482500
# Q2 2012              0.634888
# Q1 2012              0.229859
# Q4 2011              1.208018
# Q3 2011              1.827117
# Q2 2011              2.496876
# Q1 2011              0.418331
# Q4 2010              1.024206
# Q3 2010              0.331211
# Q2 2010              0.519211
# Q1 2010             -0.297459
# Q4 2009             -0.542920
# Q3 2009              1.352411
# Q2 2009              0.238329
# Q1 2009             -0.636401
# Q4 2008             -0.188362
# Q3 2008             -0.494621
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    ABI
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    ABI
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    ABI
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    ABI
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    ABI
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    ABI
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    ABI
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    ABI
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    ABI
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    ABI
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    ABI
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    ABI
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    ABI
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    ABI
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    ABI
#
#          net_sales_normalized
# index
# Q1 2017              1.729115
# Q4 2016              1.481572
# Q3 2016              1.298512
# Q2 2016              1.096266
# Q1 2016              0.335156
# Q4 2015              0.340773
# Q3 2015              0.141204
# Q2 2015             -0.045641
# Q1 2015             -0.764292
# Q4 2014             -0.719398
# Q3 2014             -0.727370
# Q2 2014             -0.362840
# Q1 2014             -1.515276
# Q4 2013             -1.169026
# Q3 2013             -1.118756
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    ABT
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    ABT
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    ABT
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    ABT
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    ABT
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    ABT
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    ABT
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    ABT
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    ABT
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    ABT
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    ABT
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    ABT
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    ABT
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    ABT
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    ABT
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    ABT
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    ABT
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    ABT
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    ABT
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    ABT
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    ABT
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    ABT
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    ABT
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    ABT
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    ABT
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    ABT
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    ABT
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    ABT
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    ABT
# Q4 2009  {'quarter': 'Q4 2009', 'income status': {'Net ...    ABT
# Q3 2009  {'quarter': 'Q3 2009', 'income status': {'Net ...    ABT
# Q2 2009  {'quarter': 'Q2 2009', 'income status': {'Net ...    ABT
# Q1 2009  {'quarter': 'Q1 2009', 'income status': {'Net ...    ABT
# Q4 2008  {'quarter': 'Q4 2008', 'income status': {'Net ...    ABT
# Q3 2008  {'quarter': 'Q3 2008', 'income status': {'Net ...    ABT
# Q2 2008  {'quarter': 'Q2 2008', 'income status': {'Net ...    ABT
# Q1 2008  {'quarter': 'Q1 2008', 'income status': {'Net ...    ABT
# Q4 2007  {'quarter': 'Q4 2007', 'income status': {'Net ...    ABT
# Q3 2007  {'quarter': 'Q3 2007', 'income status': {'Net ...    ABT
# Q2 2007  {'quarter': 'Q2 2007', 'income status': {'Net ...    ABT
# Q1 2007  {'quarter': 'Q1 2007', 'income status': {'Net ...    ABT
# Q4 2006  {'quarter': 'Q4 2006', 'income status': {'Net ...    ABT
# Q3 2006  {'quarter': 'Q3 2006', 'income status': {'Net ...    ABT
# Q2 2006  {'quarter': 'Q2 2006', 'income status': {'Net ...    ABT
# Q1 2006  {'quarter': 'Q1 2006', 'income status': {'Net ...    ABT
#
#          net_sales_normalized
# index
# Q1 2017             -0.833251
# Q4 2016             -1.267975
# Q3 2016             -0.236388
# Q2 2016             -0.309354
# Q1 2016             -0.807182
# Q4 2015             -0.328809
# Q3 2015              0.013166
# Q2 2015             -0.353896
# Q1 2015             -0.465951
# Q4 2014             -0.819397
# Q3 2014              0.100731
# Q2 2014             -0.143371
# Q1 2014             -0.961693
# Q4 2013             -0.325532
# Q3 2013              0.209747
# Q2 2013              0.406238
# Q1 2013              0.438356
# Q4 2012             -0.718753
# Q3 2012              1.387533
# Q2 2012              1.551460
# Q1 2012              1.477422
# Q4 2011             -0.216992
# Q3 2011              2.507400
# Q2 2011              1.512698
# Q1 2011              0.747916
# Q4 2010              2.307066
# Q3 2010              1.367184
# Q2 2010              0.047698
# Q1 2010              1.495596
# Q4 2009              1.561322
# Q3 2009             -0.170871
# Q2 2009             -0.040761
# Q1 2009             -0.341263
# Q4 2008             -0.660446
# Q3 2008              0.014418
# Q2 2008              0.093580
# Q1 2008             -0.539334
# Q4 2007              0.272255
# Q3 2007             -1.048721
# Q2 2007             -0.195243
# Q1 2007             -1.422725
# Q4 2006             -1.325895
# Q3 2006             -1.102202
# Q2 2006             -1.455141
# Q1 2006             -1.420640
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    ACB
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    ACB
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    ACB
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    ACB
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    ACB
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    ACB
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    ACB
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    ACB
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    ACB
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    ACB
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    ACB
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    ACB
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    ACB
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    ACB
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    ACB
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    ACB
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    ACB
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    ACB
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    ACB
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    ACB
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    ACB
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    ACB
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    ACB
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    ACB
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    ACB
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    ACB
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    ACB
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    ACB
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    ACB
# Q4 2009  {'quarter': 'Q4 2009', 'income status': {'Net ...    ACB
# Q3 2009  {'quarter': 'Q3 2009', 'income status': {'Net ...    ACB
# Q2 2009  {'quarter': 'Q2 2009', 'income status': {'Net ...    ACB
# Q1 2009  {'quarter': 'Q1 2009', 'income status': {'Net ...    ACB
# Q4 2008  {'quarter': 'Q4 2008', 'income status': {'Net ...    ACB
# Q3 2008  {'quarter': 'Q3 2008', 'income status': {'Net ...    ACB
# Q2 2008  {'quarter': 'Q2 2008', 'income status': {'Net ...    ACB
# Q1 2008  {'quarter': 'Q1 2008', 'income status': {'Net ...    ACB
#
#          net_sales_normalized
# index
# Q1 2017             -1.076648
# Q4 2016             -1.052541
# Q3 2016             -1.235120
# Q2 2016             -1.203498
# Q1 2016             -1.282711
# Q4 2015             -1.236457
# Q3 2015             -1.352042
# Q2 2015             -0.117080
# Q1 2015             -0.135244
# Q4 2014             -0.087924
# Q3 2014             -0.023137
# Q2 2014              0.001454
# Q1 2014             -0.145081
# Q4 2013             -0.228888
# Q3 2013              0.152316
# Q2 2013              0.190086
# Q1 2013              0.359354
# Q4 2012              0.562086
# Q3 2012              0.917481
# Q2 2012              1.717054
# Q1 2012              1.751463
# Q4 2011              2.245285
# Q3 2011              2.030750
# Q2 2011              1.716535
# Q1 2011              0.948077
# Q4 2010              0.681063
# Q3 2010              0.154949
# Q2 2010             -0.138837
# Q1 2010             -0.372183
# Q4 2009                   NaN
# Q3 2009                   NaN
# Q2 2009             -0.921564
# Q1 2009             -1.031310
# Q4 2008              0.179714
# Q3 2008             -0.260431
# Q2 2008             -0.575129
# Q1 2008             -1.131841
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    ACC
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    ACC
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    ACC
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    ACC
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    ACC
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    ACC
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    ACC
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    ACC
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    ACC
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    ACC
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    ACC
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    ACC
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    ACC
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    ACC
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    ACC
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    ACC
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    ACC
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    ACC
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    ACC
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    ACC
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    ACC
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    ACC
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    ACC
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    ACC
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    ACC
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    ACC
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    ACC
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    ACC
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    ACC
#
#          net_sales_normalized
# index
# Q1 2017             -1.317954
# Q4 2016              1.031975
# Q3 2016              0.305863
# Q2 2016              0.779712
# Q1 2016              0.217790
# Q4 2015              1.709612
# Q3 2015             -0.931995
# Q2 2015             -0.743108
# Q1 2015             -0.092330
# Q4 2014              2.182679
# Q3 2014             -0.607709
# Q2 2014             -1.234848
# Q1 2014             -0.654115
# Q4 2013             -0.586645
# Q3 2013             -0.932592
# Q2 2013              0.664090
# Q1 2013              1.302542
# Q4 2012             -1.714722
# Q3 2012             -0.141449
# Q2 2012              1.289021
# Q1 2012              1.767469
# Q4 2011             -0.361058
# Q3 2011             -0.827364
# Q2 2011              0.125715
# Q1 2011              0.373471
# Q4 2010              0.143054
# Q3 2010             -0.066207
# Q2 2010             -1.343341
# Q1 2010             -0.337556
#                                                       data ticker  \
# index
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    ACE
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    ACE
# Q3 2009  {'quarter': 'Q3 2009', 'income status': {'Net ...    ACE
# Q3 2008  {'quarter': 'Q3 2008', 'income status': {'Net ...    ACE
#
#          net_sales_normalized
# index
# Q3 2015              0.408178
# Q3 2014              1.437746
# Q3 2009             -1.099825
# Q3 2008             -0.746099
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    ACL
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    ACL
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    ACL
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    ACL
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    ACL
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    ACL
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    ACL
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    ACL
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    ACL
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    ACL
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    ACL
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    ACL
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    ACL
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    ACL
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    ACL
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    ACL
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    ACL
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    ACL
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    ACL
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    ACL
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    ACL
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    ACL
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    ACL
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    ACL
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    ACL
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    ACL
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    ACL
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    ACL
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    ACL
# Q4 2009  {'quarter': 'Q4 2009', 'income status': {'Net ...    ACL
# Q3 2009  {'quarter': 'Q3 2009', 'income status': {'Net ...    ACL
# Q2 2009  {'quarter': 'Q2 2009', 'income status': {'Net ...    ACL
# Q1 2009  {'quarter': 'Q1 2009', 'income status': {'Net ...    ACL
# Q4 2008  {'quarter': 'Q4 2008', 'income status': {'Net ...    ACL
# Q3 2008  {'quarter': 'Q3 2008', 'income status': {'Net ...    ACL
# Q2 2008  {'quarter': 'Q2 2008', 'income status': {'Net ...    ACL
# Q1 2008  {'quarter': 'Q1 2008', 'income status': {'Net ...    ACL
# Q4 2007  {'quarter': 'Q4 2007', 'income status': {'Net ...    ACL
# Q3 2007  {'quarter': 'Q3 2007', 'income status': {'Net ...    ACL
# Q2 2007  {'quarter': 'Q2 2007', 'income status': {'Net ...    ACL
# Q4 2006  {'quarter': 'Q4 2006', 'income status': {'Net ...    ACL
# Q3 2006  {'quarter': 'Q3 2006', 'income status': {'Net ...    ACL
# Q2 2006  {'quarter': 'Q2 2006', 'income status': {'Net ...    ACL
#
#          net_sales_normalized
# index
# Q1 2017              0.655116
# Q4 2016              1.044039
# Q3 2016              1.834173
# Q2 2016              1.404089
# Q1 2016              0.490431
# Q4 2015              0.688059
# Q3 2015              0.676822
# Q2 2015              1.509761
# Q1 2015             -0.150890
# Q4 2014              0.232213
# Q3 2014             -0.858782
# Q2 2014             -0.326529
# Q1 2014             -0.134883
# Q4 2013              0.408863
# Q3 2013             -0.038198
# Q2 2013              0.551384
# Q1 2013             -0.221800
# Q4 2012              0.175975
# Q3 2012              0.223954
# Q2 2012              0.915570
# Q1 2012             -0.009203
# Q4 2011              1.614651
# Q3 2011              1.019113
# Q2 2011              1.880198
# Q1 2011              0.239462
# Q4 2010              0.851370
# Q3 2010              0.378359
# Q2 2010              0.453958
# Q1 2010              0.245673
# Q4 2009              0.239826
# Q3 2009             -0.798232
# Q2 2009             -0.825812
# Q1 2009             -1.513980
# Q4 2008             -1.396061
# Q3 2008             -0.590782
# Q2 2008             -0.715519
# Q1 2008             -1.152448
# Q4 2007             -1.018778
# Q3 2007             -1.360679
# Q2 2007             -1.363738
# Q4 2006             -1.653672
# Q3 2006             -2.083554
# Q2 2006             -1.519517
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    ACM
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    ACM
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    ACM
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    ACM
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    ACM
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    ACM
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    ACM
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    ACM
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    ACM
#
#          net_sales_normalized
# index
# Q1 2017             -1.264159
# Q4 2016             -1.185082
# Q3 2016             -1.214097
# Q2 2016              0.656089
# Q1 2016              0.013097
# Q4 2015              1.491158
# Q3 2015              1.183281
# Q2 2015              0.617028
# Q1 2015             -0.297316
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    ADC
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    ADC
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    ADC
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    ADC
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    ADC
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    ADC
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    ADC
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    ADC
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    ADC
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    ADC
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    ADC
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    ADC
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    ADC
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    ADC
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    ADC
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    ADC
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    ADC
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    ADC
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    ADC
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    ADC
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    ADC
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    ADC
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    ADC
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    ADC
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    ADC
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    ADC
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    ADC
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    ADC
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    ADC
# Q4 2009  {'quarter': 'Q4 2009', 'income status': {'Net ...    ADC
#
#          net_sales_normalized
# index
# Q1 2017              0.470136
# Q4 2016              0.787571
# Q3 2016              2.859374
# Q2 2016              0.167596
# Q1 2016              0.172839
# Q4 2015              0.502636
# Q3 2015              2.437423
# Q2 2015              0.019157
# Q1 2015             -0.294772
# Q4 2014             -0.126332
# Q3 2014              2.164086
# Q2 2014             -0.406753
# Q1 2014             -0.549081
# Q4 2013             -0.120047
# Q3 2013              1.102576
# Q2 2013             -0.471268
# Q1 2013             -0.785543
# Q4 2012             -0.454323
# Q3 2012              0.695452
# Q2 2012             -0.652798
# Q1 2012             -0.784571
# Q4 2011             -0.247549
# Q3 2011             -0.393523
# Q2 2011             -1.075478
# Q1 2011             -0.868566
# Q4 2010             -0.553075
# Q3 2010             -0.804884
# Q2 2010             -0.917039
# Q1 2010             -0.946449
# Q4 2009             -0.926796
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    ADP
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    ADP
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    ADP
# Q3 2009  {'quarter': 'Q3 2009', 'income status': {'Net ...    ADP
#
#          net_sales_normalized
# index
# Q1 2017             -1.340220
# Q4 2016             -0.407351
# Q1 2016              0.368377
# Q3 2009              1.379193
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    ADS
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    ADS
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    ADS
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    ADS
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    ADS
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    ADS
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    ADS
#
#          net_sales_normalized
# index
# Q1 2017             -0.625489
# Q4 2016              0.386732
# Q3 2016              0.135681
# Q2 2016             -0.976753
# Q1 2016             -0.467221
# Q3 2015              2.200369
# Q1 2015             -0.653320
#                                                       data ticker  \
# index
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    AGC
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    AGC
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    AGC
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    AGC
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    AGC
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    AGC
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    AGC
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    AGC
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    AGC
# Q4 2009  {'quarter': 'Q4 2009', 'income status': {'Net ...    AGC
# Q3 2009  {'quarter': 'Q3 2009', 'income status': {'Net ...    AGC
# Q2 2009  {'quarter': 'Q2 2009', 'income status': {'Net ...    AGC
# Q1 2009  {'quarter': 'Q1 2009', 'income status': {'Net ...    AGC
# Q2 2008  {'quarter': 'Q2 2008', 'income status': {'Net ...    AGC
# Q1 2008  {'quarter': 'Q1 2008', 'income status': {'Net ...    AGC
#
#          net_sales_normalized
# index
# Q1 2012             -1.240013
# Q4 2011             -1.051797
# Q3 2011             -1.227010
# Q2 2011             -1.097748
# Q1 2011             -0.929090
# Q4 2010             -0.385101
# Q3 2010             -0.826176
# Q2 2010              0.837027
# Q1 2010             -0.110043
# Q4 2009              0.417137
# Q3 2009              1.137695
# Q2 2009              1.343775
# Q1 2009              1.544872
# Q2 2008              0.393533
# Q1 2008              1.192939
#                                                       data ticker  \
# index
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    AGD
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    AGD
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    AGD
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    AGD
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    AGD
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    AGD
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    AGD
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    AGD
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    AGD
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    AGD
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    AGD
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    AGD
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    AGD
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    AGD
# Q4 2009  {'quarter': 'Q4 2009', 'income status': {'Net ...    AGD
# Q3 2009  {'quarter': 'Q3 2009', 'income status': {'Net ...    AGD
# Q2 2009  {'quarter': 'Q2 2009', 'income status': {'Net ...    AGD
# Q1 2009  {'quarter': 'Q1 2009', 'income status': {'Net ...    AGD
#
#          net_sales_normalized
# index
# Q2 2013              0.401229
# Q1 2013              0.994936
# Q4 2012              0.936479
# Q3 2012              0.710459
# Q2 2012              0.145734
# Q1 2012              1.209475
# Q4 2011              0.410830
# Q3 2011              0.579892
# Q2 2011              1.766300
# Q1 2011             -0.103181
# Q4 2010              0.739039
# Q3 2010             -0.698120
# Q2 2010             -1.083354
# Q1 2010             -1.706805
# Q4 2009             -0.667168
# Q3 2009             -0.865257
# Q2 2009             -1.072343
# Q1 2009             -1.698144
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    AGF
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    AGF
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    AGF
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    AGF
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    AGF
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    AGF
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    AGF
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    AGF
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    AGF
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    AGF
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    AGF
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    AGF
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    AGF
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    AGF
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    AGF
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    AGF
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    AGF
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    AGF
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    AGF
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    AGF
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    AGF
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    AGF
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    AGF
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    AGF
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    AGF
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    AGF
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    AGF
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    AGF
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    AGF
# Q4 2009  {'quarter': 'Q4 2009', 'income status': {'Net ...    AGF
# Q3 2009  {'quarter': 'Q3 2009', 'income status': {'Net ...    AGF
# Q2 2009  {'quarter': 'Q2 2009', 'income status': {'Net ...    AGF
# Q1 2009  {'quarter': 'Q1 2009', 'income status': {'Net ...    AGF
# Q4 2008  {'quarter': 'Q4 2008', 'income status': {'Net ...    AGF
# Q3 2008  {'quarter': 'Q3 2008', 'income status': {'Net ...    AGF
# Q2 2008  {'quarter': 'Q2 2008', 'income status': {'Net ...    AGF
# Q1 2008  {'quarter': 'Q1 2008', 'income status': {'Net ...    AGF
# Q4 2007  {'quarter': 'Q4 2007', 'income status': {'Net ...    AGF
# Q3 2007  {'quarter': 'Q3 2007', 'income status': {'Net ...    AGF
# Q2 2007  {'quarter': 'Q2 2007', 'income status': {'Net ...    AGF
# Q1 2007  {'quarter': 'Q1 2007', 'income status': {'Net ...    AGF
# Q4 2006  {'quarter': 'Q4 2006', 'income status': {'Net ...    AGF
# Q3 2006  {'quarter': 'Q3 2006', 'income status': {'Net ...    AGF
# Q2 2006  {'quarter': 'Q2 2006', 'income status': {'Net ...    AGF
# Q1 2006  {'quarter': 'Q1 2006', 'income status': {'Net ...    AGF
#
#          net_sales_normalized
# index
# Q1 2017             -0.379695
# Q4 2016              0.415156
# Q3 2016              0.372412
# Q2 2016              1.203793
# Q1 2016              2.521914
# Q4 2015              0.282421
# Q3 2015              0.435505
# Q2 2015             -0.138456
# Q1 2015             -0.359498
# Q4 2014              0.319961
# Q3 2014              0.448934
# Q2 2014              0.603345
# Q1 2014              0.725265
# Q4 2013              1.102638
# Q3 2013              1.174594
# Q2 2013              1.269553
# Q1 2013              0.301899
# Q4 2012              0.293357
# Q3 2012              0.690870
# Q2 2012              0.993826
# Q1 2012              0.192439
# Q4 2011              0.523852
# Q3 2011              0.190478
# Q2 2011              0.451155
# Q1 2011              0.395594
# Q4 2010             -0.502593
# Q3 2010             -0.657968
# Q2 2010             -0.728777
# Q1 2010             -0.788398
# Q4 2009             -0.713386
# Q3 2009             -0.783422
# Q2 2009             -1.201221
# Q1 2009             -1.664431
# Q4 2008             -0.303052
# Q3 2008              1.030003
# Q2 2008             -0.732395
# Q1 2008             -1.020564
# Q4 2007             -0.953232
# Q3 2007             -1.209074
# Q2 2007             -1.323676
# Q1 2007             -1.325736
# Q4 2006              2.737689
# Q3 2006             -1.101795
# Q2 2006             -1.092467
# Q1 2006             -1.696819
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    AGM
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    AGM
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    AGM
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    AGM
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    AGM
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    AGM
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    AGM
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    AGM
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    AGM
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    AGM
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    AGM
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    AGM
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    AGM
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    AGM
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    AGM
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    AGM
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    AGM
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    AGM
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    AGM
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    AGM
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    AGM
#
#          net_sales_normalized
# index
# Q1 2017              1.085293
# Q4 2016             -0.597229
# Q3 2016              0.624936
# Q2 2016             -0.729180
# Q1 2016              0.025013
# Q4 2015              1.739057
# Q3 2015             -0.379859
# Q2 2015              0.652511
# Q1 2015             -0.875597
# Q4 2014             -1.166061
# Q3 2014              0.367570
# Q2 2014              0.414703
# Q1 2014             -1.643683
# Q4 2013             -1.340167
# Q3 2013              0.230125
# Q2 2013             -0.045510
# Q1 2013             -0.781435
# Q4 2012              0.079991
# Q3 2012              2.011663
# Q2 2012              1.437586
# Q1 2012             -1.109726
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    AGR
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    AGR
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    AGR
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    AGR
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    AGR
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    AGR
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    AGR
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    AGR
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    AGR
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    AGR
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    AGR
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    AGR
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    AGR
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    AGR
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    AGR
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    AGR
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    AGR
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    AGR
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    AGR
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    AGR
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    AGR
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    AGR
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    AGR
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    AGR
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    AGR
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    AGR
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    AGR
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    AGR
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    AGR
# Q4 2009  {'quarter': 'Q4 2009', 'income status': {'Net ...    AGR
# Q3 2009  {'quarter': 'Q3 2009', 'income status': {'Net ...    AGR
# Q2 2009  {'quarter': 'Q2 2009', 'income status': {'Net ...    AGR
# Q1 2009  {'quarter': 'Q1 2009', 'income status': {'Net ...    AGR
#
#          net_sales_normalized
# index
# Q1 2017             -0.893288
# Q4 2016             -1.046917
# Q3 2016             -1.047604
# Q2 2016             -0.985447
# Q1 2016             -1.154827
# Q4 2015             -0.963189
# Q3 2015             -0.950722
# Q2 2015             -0.993949
# Q1 2015             -1.040769
# Q4 2014             -0.774692
# Q3 2014             -0.814584
# Q2 2014             -0.745485
# Q1 2014             -0.704348
# Q4 2013             -0.720300
# Q3 2013             -0.797043
# Q2 2013             -0.521713
# Q1 2013             -0.391881
# Q4 2012             -0.063869
# Q3 2012              0.316495
# Q2 2012              0.675188
# Q1 2012              0.212985
# Q4 2011              0.323065
# Q3 2011              0.648378
# Q2 2011              1.676435
# Q1 2011              1.697934
# Q4 2010              1.961040
# Q3 2010              1.644250
# Q2 2010              1.569440
# Q1 2010              1.545200
# Q4 2009              0.786712
# Q3 2009              0.798650
# Q2 2009              0.642280
# Q1 2009              0.112575
#                                                       data ticker  \
# index
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    ALP
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    ALP
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    ALP
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    ALP
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    ALP
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    ALP
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    ALP
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    ALP
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    ALP
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    ALP
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    ALP
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    ALP
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    ALP
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    ALP
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    ALP
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    ALP
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    ALP
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    ALP
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    ALP
# Q4 2009  {'quarter': 'Q4 2009', 'income status': {'Net ...    ALP
# Q3 2009  {'quarter': 'Q3 2009', 'income status': {'Net ...    ALP
# Q2 2009  {'quarter': 'Q2 2009', 'income status': {'Net ...    ALP
# Q1 2009  {'quarter': 'Q1 2009', 'income status': {'Net ...    ALP
# Q4 2008  {'quarter': 'Q4 2008', 'income status': {'Net ...    ALP
# Q3 2008  {'quarter': 'Q3 2008', 'income status': {'Net ...    ALP
# Q2 2008  {'quarter': 'Q2 2008', 'income status': {'Net ...    ALP
# Q1 2008  {'quarter': 'Q1 2008', 'income status': {'Net ...    ALP
# Q4 2007  {'quarter': 'Q4 2007', 'income status': {'Net ...    ALP
# Q3 2007  {'quarter': 'Q3 2007', 'income status': {'Net ...    ALP
# Q2 2007  {'quarter': 'Q2 2007', 'income status': {'Net ...    ALP
# ...
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    ASM
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    ASM
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    ASM
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    ASM
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    ASM
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    ASM
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    ASM
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    ASM
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    ASM
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    ASM
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    ASM
# Q4 2009  {'quarter': 'Q4 2009', 'income status': {'Net ...    ASM
# Q3 2009  {'quarter': 'Q3 2009', 'income status': {'Net ...    ASM
# Q2 2008  {'quarter': 'Q2 2008', 'income status': {'Net ...    ASM
# Q1 2008  {'quarter': 'Q1 2008', 'income status': {'Net ...    ASM
# Q2 2007  {'quarter': 'Q2 2007', 'income status': {'Net ...    ASM
# Q1 2007  {'quarter': 'Q1 2007', 'income status': {'Net ...    ASM
#
#          net_sales_normalized
# index
# Q1 2017              0.397605
# Q4 2016              3.223572
# Q3 2016              1.886526
# Q2 2016             -0.017084
# Q1 2016             -0.362896
# Q4 2015              0.019036
# Q3 2015              0.076577
# Q2 2015             -0.183191
# Q1 2015             -0.611321
# Q4 2014              2.750540
# Q3 2014             -0.092873
# Q2 2014              0.271355
# Q1 2014              0.003133
# Q4 2013              0.779694
# Q3 2013             -0.320076
# Q2 2013              0.150045
# Q1 2013              0.179166
# Q4 2012             -0.150976
# Q3 2012              0.430077
# Q2 2012              0.087007
# Q1 2012             -0.261224
# Q4 2011             -0.609953
# Q3 2011              0.069187
# Q2 2011             -0.080473
# Q1 2011             -0.118621
# Q4 2010             -0.635023
# Q3 2010             -1.003963
# Q2 2010             -0.052205
# Q1 2010             -0.922012
# Q4 2009             -0.924298
# Q3 2009              1.190414
# Q2 2008             -1.225769
# Q1 2008             -1.361017
# Q2 2007             -1.165240
# Q1 2007             -1.415718
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    ASP
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    ASP
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    ASP
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    ASP
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    ASP
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    ASP
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    ASP
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    ASP
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    ASP
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    ASP
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    ASP
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    ASP
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    ASP
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    ASP
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    ASP
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    ASP
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    ASP
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    ASP
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    ASP
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    ASP
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    ASP
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    ASP
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    ASP
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    ASP
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    ASP
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    ASP
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    ASP
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    ASP
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    ASP
# Q4 2009  {'quarter': 'Q4 2009', 'income status': {'Net ...    ASP
# Q3 2009  {'quarter': 'Q3 2009', 'income status': {'Net ...    ASP
# Q2 2009  {'quarter': 'Q2 2009', 'income status': {'Net ...    ASP
# Q1 2009  {'quarter': 'Q1 2009', 'income status': {'Net ...    ASP
# Q4 2008  {'quarter': 'Q4 2008', 'income status': {'Net ...    ASP
# Q3 2008  {'quarter': 'Q3 2008', 'income status': {'Net ...    ASP
# Q2 2008  {'quarter': 'Q2 2008', 'income status': {'Net ...    ASP
# Q1 2008  {'quarter': 'Q1 2008', 'income status': {'Net ...    ASP
# Q4 2007  {'quarter': 'Q4 2007', 'income status': {'Net ...    ASP
# Q3 2007  {'quarter': 'Q3 2007', 'income status': {'Net ...    ASP
# Q2 2007  {'quarter': 'Q2 2007', 'income status': {'Net ...    ASP
# Q1 2007  {'quarter': 'Q1 2007', 'income status': {'Net ...    ASP
#
#          net_sales_normalized
# index
# Q1 2017              0.190494
# Q4 2016             -0.562624
# Q3 2016             -1.224077
# Q2 2016             -1.050094
# Q1 2016             -0.834320
# Q4 2015             -1.062368
# Q3 2015             -1.290567
# Q2 2015             -0.654768
# Q1 2015             -0.754947
# Q4 2014              0.009761
# Q3 2014              0.386165
# Q2 2014             -0.109125
# Q1 2014              0.487742
# Q4 2013              1.289431
# Q3 2013              0.261081
# Q2 2013              0.335766
# Q1 2013              0.376198
# Q4 2012              0.773297
# Q3 2012              0.286276
# Q2 2012              0.242891
# Q1 2012              1.171305
# Q4 2011              2.061706
# Q3 2011              1.507315
# Q2 2011              1.808988
# Q1 2011              2.032873
# Q4 2010              1.770600
# Q3 2010              0.582211
# Q2 2010              0.397745
# Q1 2010              0.497925
# Q4 2009              0.576276
# Q3 2009             -0.644013
# Q2 2009             -0.471774
# Q1 2009             -1.015026
# Q4 2008             -0.728543
# Q3 2008             -0.613933
# Q2 2008             -0.830120
# Q1 2008             -0.836327
# Q4 2007             -0.377268
# Q3 2007             -0.732425
# Q2 2007             -0.924598
# Q1 2007             -2.329127
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    ATA
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    ATA
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    ATA
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    ATA
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    ATA
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    ATA
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    ATA
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    ATA
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    ATA
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    ATA
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    ATA
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    ATA
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    ATA
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    ATA
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    ATA
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    ATA
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    ATA
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    ATA
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    ATA
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    ATA
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    ATA
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    ATA
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    ATA
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    ATA
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    ATA
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    ATA
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    ATA
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    ATA
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    ATA
# Q4 2009  {'quarter': 'Q4 2009', 'income status': {'Net ...    ATA
# Q3 2009  {'quarter': 'Q3 2009', 'income status': {'Net ...    ATA
# Q2 2009  {'quarter': 'Q2 2009', 'income status': {'Net ...    ATA
# Q1 2009  {'quarter': 'Q1 2009', 'income status': {'Net ...    ATA
# Q4 2008  {'quarter': 'Q4 2008', 'income status': {'Net ...    ATA
# Q3 2008  {'quarter': 'Q3 2008', 'income status': {'Net ...    ATA
# Q2 2008  {'quarter': 'Q2 2008', 'income status': {'Net ...    ATA
#
#          net_sales_normalized
# index
# Q1 2017             -1.497558
# Q4 2016             -1.219428
# Q3 2016             -1.271990
# Q2 2016             -1.245946
# Q1 2016             -1.356176
# Q4 2015             -1.274090
# Q3 2015             -1.180579
# Q2 2015             -1.227486
# Q1 2015             -0.992272
# Q4 2014             -0.376623
# Q3 2014             -0.290186
# Q2 2014             -0.258316
# Q1 2014             -0.538148
# Q4 2013             -0.605973
# Q3 2013             -0.798631
# Q2 2013             -0.447588
# Q1 2013              0.091195
# Q4 2012              0.899236
# Q3 2012              0.355990
# Q2 2012              0.091894
# Q1 2012              0.290453
# Q4 2011              1.768143
# Q3 2011              1.308515
# Q2 2011              0.873135
# Q1 2011              0.645562
# Q4 2010              1.917677
# Q3 2010              2.117862
# Q2 2010              0.159587
# Q1 2010              1.062861
# Q4 2009             -0.217765
# Q3 2009              1.158622
# Q2 2009              0.555419
# Q1 2009              0.511538
# Q4 2008              1.263065
# Q3 2008             -0.125446
# Q2 2008             -0.146554
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    ATS
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    ATS
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    ATS
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    ATS
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    ATS
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    ATS
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    ATS
#
#          net_sales_normalized
# index
# Q1 2017              0.651039
# Q4 2016              1.896823
# Q3 2016             -0.368268
# Q2 2016             -0.707827
# Q1 2016             -1.525225
# Q4 2015             -0.056428
# Q3 2015              0.109886
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    AVF
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    AVF
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    AVF
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    AVF
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    AVF
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    AVF
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    AVF
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    AVF
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    AVF
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    AVF
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    AVF
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    AVF
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    AVF
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    AVF
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    AVF
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    AVF
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    AVF
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    AVF
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    AVF
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    AVF
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    AVF
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    AVF
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    AVF
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    AVF
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    AVF
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    AVF
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    AVF
#
#          net_sales_normalized
# index
# Q1 2017             -1.076640
# Q4 2016             -1.022430
# Q3 2016             -1.041357
# Q2 2016             -1.055931
# Q1 2016             -1.102595
# Q3 2015             -1.095996
# Q2 2015             -1.095015
# Q1 2015             -1.124276
# Q4 2014             -1.180778
# Q3 2014             -1.105644
# Q2 2014             -1.143656
# Q1 2014             -0.720259
# Q4 2013              0.305487
# Q3 2013              0.552071
# Q2 2013              0.834018
# Q1 2013              0.613927
# Q4 2012              0.950637
# Q3 2012              0.903111
# Q2 2012              0.843217
# Q1 2012              1.337398
# Q4 2011              1.400098
# Q3 2011              1.335479
# Q2 2011              1.089848
# Q1 2011              0.201169
# Q4 2010              1.434352
# Q3 2010              0.693211
# Q2 2010              0.270552
#                                                       data ticker  \
# index
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    AVS
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    AVS
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    AVS
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    AVS
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    AVS
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    AVS
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    AVS
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    AVS
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    AVS
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    AVS
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    AVS
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    AVS
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    AVS
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    AVS
#
#          net_sales_normalized
# index
# Q2 2013             -0.978446
# Q1 2013             -1.081330
# Q4 2012             -0.283405
# Q3 2012             -1.119373
# Q2 2012              0.199253
# Q1 2012             -0.612786
# Q4 2011             -0.182838
# Q3 2011             -0.628665
# Q2 2011              0.105191
# Q1 2011             -0.340636
# Q4 2010              0.537896
# Q3 2010              0.580130
# Q2 2010              2.825587
# Q1 2010              0.979423

# %%
dict_main['AAA']
# Out:
#                                                       data ticker  \
# index
# Q1 2017  {'quarter': 'Q1 2017', 'income status': {'Net ...    AAA
# Q4 2016  {'quarter': 'Q4 2016', 'income status': {'Net ...    AAA
# Q3 2016  {'quarter': 'Q3 2016', 'income status': {'Net ...    AAA
# Q2 2016  {'quarter': 'Q2 2016', 'income status': {'Net ...    AAA
# Q1 2016  {'quarter': 'Q1 2016', 'income status': {'Net ...    AAA
# Q4 2015  {'quarter': 'Q4 2015', 'income status': {'Net ...    AAA
# Q3 2015  {'quarter': 'Q3 2015', 'income status': {'Net ...    AAA
# Q2 2015  {'quarter': 'Q2 2015', 'income status': {'Net ...    AAA
# Q1 2015  {'quarter': 'Q1 2015', 'income status': {'Net ...    AAA
# Q4 2014  {'quarter': 'Q4 2014', 'income status': {'Net ...    AAA
# Q3 2014  {'quarter': 'Q3 2014', 'income status': {'Net ...    AAA
# Q2 2014  {'quarter': 'Q2 2014', 'income status': {'Net ...    AAA
# Q1 2014  {'quarter': 'Q1 2014', 'income status': {'Net ...    AAA
# Q4 2013  {'quarter': 'Q4 2013', 'income status': {'Net ...    AAA
# Q3 2013  {'quarter': 'Q3 2013', 'income status': {'Net ...    AAA
# Q2 2013  {'quarter': 'Q2 2013', 'income status': {'Net ...    AAA
# Q1 2013  {'quarter': 'Q1 2013', 'income status': {'Net ...    AAA
# Q4 2012  {'quarter': 'Q4 2012', 'income status': {'Net ...    AAA
# Q3 2012  {'quarter': 'Q3 2012', 'income status': {'Net ...    AAA
# Q2 2012  {'quarter': 'Q2 2012', 'income status': {'Net ...    AAA
# Q1 2012  {'quarter': 'Q1 2012', 'income status': {'Net ...    AAA
# Q4 2011  {'quarter': 'Q4 2011', 'income status': {'Net ...    AAA
# Q3 2011  {'quarter': 'Q3 2011', 'income status': {'Net ...    AAA
# Q2 2011  {'quarter': 'Q2 2011', 'income status': {'Net ...    AAA
# Q1 2011  {'quarter': 'Q1 2011', 'income status': {'Net ...    AAA
# Q4 2010  {'quarter': 'Q4 2010', 'income status': {'Net ...    AAA
# Q3 2010  {'quarter': 'Q3 2010', 'income status': {'Net ...    AAA
# Q2 2010  {'quarter': 'Q2 2010', 'income status': {'Net ...    AAA
# Q1 2010  {'quarter': 'Q1 2010', 'income status': {'Net ...    AAA
#
#          net_sales_normalized
# index
# Q1 2017              2.698701
# Q4 2016              2.275765
# Q3 2016              1.363909
# Q2 2016              1.236116
# Q1 2016              0.589673
# Q4 2015              0.838929
# Q3 2015              0.892971
# Q2 2015              0.213419
# Q1 2015             -0.137155
# Q4 2014              0.732863
# Q3 2014              0.491223
# Q2 2014              0.315297
# Q1 2014             -0.103749
# Q4 2013             -0.067433
# Q3 2013             -0.201722
# Q2 2013             -0.429527
# Q1 2013             -0.651645
# Q4 2012             -0.368346
# Q3 2012             -0.652654
# Q2 2012             -0.840598
# Q1 2012             -0.507881
# Q4 2011             -0.338561
# Q3 2011             -0.797336
# Q2 2011             -0.929504
# Q1 2011             -0.990996
# Q4 2010             -0.951853
# Q3 2010             -0.945295
# Q2 2010             -1.240397
# Q1 2010             -1.494214
